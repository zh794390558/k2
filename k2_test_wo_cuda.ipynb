# %%
import k2.version

# %%
k2.version.version.main()
# Out:
# Collecting environment information...
#
# k2 version: 1.23.2
# Build type: Release
# Git SHA1: a34171ed85605b0926eebbd0463d059431f4f74a
# Git date: Tue Dec 13 16:06:38 2022
# Cuda used to build k2: 10.2
# cuDNN used to build k2: 7.6.5
# Python version used to build k2: 3.7
# OS used to build k2: Ubuntu 16.04.7 LTS
# CMake version: 3.16.0
# GCC version: 8.2.0
# CMAKE_CUDA_FLAGS:  -DONNX_NAMESPACE=onnx_c2 -gencode arch=compute_70,code=sm_70 -Xcudafe --diag_suppress=cc_clobber_ignored,--diag_suppress=integer_sign_change,--diag_suppress=useless_using_declaration,--diag_suppress=set_but_not_used,--diag_suppress=field_without_dll_interface,--diag_suppress=base_class_has_different_dll_interface,--diag_suppress=dll_interface_conflict_none_assumed,--diag_suppress=dll_interface_conflict_dllexport_assumed,--diag_suppress=implicit_return_from_non_void_function,--diag_suppress=unsigned_compare_with_zero,--diag_suppress=declared_but_not_referenced,--diag_suppress=bad_friend_decl --expt-relaxed-constexpr --expt-extended-lambda
# CMAKE_CXX_FLAGS:  -D_GLIBCXX_USE_CXX11_ABI=0 -Wno-unused-variable  -Wno-strict-overflow
# PyTorch version used to build k2: 1.12.0+cu102
# PyTorch is using Cuda:
# NVTX enabled: False
# With CUDA: False
# Disable debug: True
# Sync kernels : False
# Disable checks: False
# Max cpu memory allocate: 214748364800 bytes (or 200.0 GB)
# k2 abort: False
# __file__: /workspace/k2-fsa/k2/k2/python/k2/version/version.py
# _k2.__file__: /workspace/k2-fsa/k2/build_wo_cuda/lib/_k2.cpython-37m-x86_64-linux-gnu.so

# %%
import k2
s = '''
0 1 10 0.1
1 2 -1 0.2
2
'''
fsa = k2.Fsa.from_str(s)
fsa.draw('simple_fsa.svg')

# %%
import k2
import torch
s = '''
0 1 10 0.1
1 2 -1 0.2
2
'''
fsa = k2.Fsa.from_str(s)
fsa.aux_labels = torch.tensor([100, -1], dtype=torch.int32)
fsa.draw('simple_fst.svg')

# %%
import k2
import torch
s = '''
0 1 10 0.1
1 2 -1 0.2
2
'''
fsa = k2.Fsa.from_str(s)
fsa.output_labels = torch.tensor([100, -1], dtype=torch.int32)
fsa.draw('simple_fst.svg')
print(fsa.shape)
# Out:
# (3, None)

# %%
import k2
s = '''
0 1 10 0.1
0 2 20 0.2
1 3 -1 0
2 3 -1 0
3
'''
fsa = k2.Fsa.from_str(s)
fsa.draw('fsa2.svg')

# %%
fsa

# %%
fsa.device
# Out:
# device(type='cpu')

# %%
fsa.shape
# Out:
# (4, None)

# %%
fsa = k2.create_fsa_vec([fsa])

# %%
fsa

# %%
fsa.shape
# Out:
# (1, None, None)

# %%
total_scores = fsa.get_tot_scores(log_semiring=False, use_double_scores=False)

# %%
total_scores
# Out:
# tensor([0.2000])

# %%
total_scores = fsa.get_tot_scores(log_semiring=True, use_double_scores=False)

# %%
total_scores
# Out:
# tensor([0.8444])

# %%
fsa.__getitem__(0)

# %%
dir(fsa)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cache',
#  '_get_arc_cdf',
#  '_get_arc_post',
#  '_get_backward_scores',
#  '_get_dest_states',
#  '_get_entering_arc_batches',
#  '_get_entering_arcs',
#  '_get_forward_scores',
#  '_get_incoming_arcs',
#  '_get_leaving_arc_batches',
#  '_get_state_batches',
#  '_get_tot_scores',
#  '_invalidate_cache_',
#  '_non_tensor_attr',
#  '_properties',
#  '_tensor_attr',
#  'arcs',
#  'arcs_as_tensor',
#  'as_dict',
#  'clone',
#  'convert_attr_to_ragged_',
#  'detach',
#  'device',
#  'draw',
#  'from_dict',
#  'from_fsas',
#  'from_openfst',
#  'from_str',
#  'get_arc_post',
#  'get_backward_scores',
#  'get_filler',
#  'get_forward_scores',
#  'get_tot_scores',
#  'grad',
#  'invert',
#  'invert_',
#  'is_cpu',
#  'is_cuda',
#  'labels',
#  'named_non_tensor_attr',
#  'named_tensor_attr',
#  'num_arcs',
#  'properties',
#  'properties_str',
#  'rename_tensor_attribute_',
#  'requires_grad',
#  'requires_grad_',
#  'set_scores_stochastic_',
#  'shape',
#  'to',
#  'to_str']

# %%
fsa.device
# Out:
# device(type='cpu')

# %%
fsa.is_cpu()
# Out:
# True

# %%
fsa.is_cuda()
# Out:
# False

# %%
fsa.shape
# Out:
# (1, None, None)

# %%
import k2
import torch

nnet_output = torch.tensor([0.1, 1, 0.2, 0.5], dtype=torch.float32)
# assume nnet_output is the output of some neural network
nnet_output.requires_grad_(True)
s = '''
0 1 10 0
0 2 20 0
1 3 -1 0
2 3 -1 0
3
'''
fsa = k2.Fsa.from_str(s)
fsa.scores = nnet_output
fsa.draw('autograd_tropical.svg')
print(fsa.shape)
# Out:
# (4, None)

# %%
fsa_vec = k2.create_fsa_vec([fsa])
total_scores = fsa_vec.get_tot_scores(log_semiring=False, use_double_scores=False)

total_scores.backward()
print(nnet_output.grad)
# # It prints: tensor([0., 1., 0., 1.])
# Out:
# tensor([0., 1., 0., 1.])

# %%
fsa_vec = k2.create_fsa_vec([fsa])
total_scores = fsa_vec.get_tot_scores(log_semiring=True, use_double_scores=False)

total_scores.backward()
print(nnet_output.grad)
# # It prints: tensor([0.2315, 1.7685, 0.2315, 1.7685])
# Out:
# tensor([0.2315, 1.7685, 0.2315, 1.7685])

# %%
print(fsa.arcs.row_splits)
# Out:
# <bound method PyCapsule.row_splits of <_k2.RaggedArc object at 0x7fcb8ad2e650>>

# %%
fsa.to('cuda:0')
# Out:
# [F] /workspace/k2-fsa/k2/k2/csrc/device_guard.h:66:static int32_t k2::DeviceGuard::GetDevice() k2 compiled without CUDA support
#
#
# [ Stack-Trace: ]
# /workspace/k2-fsa/k2/build_wo_cuda/lib/libk2_log.so(k2::internal::GetStackTrace()+0x34) [0x7fcb8c59aef4]
# /workspace/k2-fsa/k2/build_wo_cuda/lib/_k2.cpython-37m-x86_64-linux-gnu.so(+0x137e8a) [0x7fcb8d034e8a]
# /workspace/k2-fsa/k2/build_wo_cuda/lib/_k2.cpython-37m-x86_64-linux-gnu.so(+0xe1b37) [0x7fcb8cfdeb37]
# /workspace/k2-fsa/k2/build_wo_cuda/lib/_k2.cpython-37m-x86_64-linux-gnu.so(+0x166f5b) [0x7fcb8d063f5b]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDef_RawFastCallKeywords+0x2eb) [0x7fccbe0aa7fb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyCFunction_FastCallKeywords+0x25) [0x7fccbe0aa8a5]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x699e) [0x7fccbe08622e]
# /usr/local/lib/libpython3.7m.so.1.0(+0x676eb) [0x7fccbe07e6eb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x750d) [0x7fccbe086d9d]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalCodeWithName+0x9a2) [0x7fccbe181d32]
# /usr/local/lib/libpython3.7m.so.1.0(PyEval_EvalCodeEx+0x3e) [0x7fccbe181fae]
# /usr/local/lib/libpython3.7m.so.1.0(PyEval_EvalCode+0x1b) [0x7fccbe181fdb]
# /usr/local/lib/libpython3.7m.so.1.0(+0x16843d) [0x7fccbe17f43d]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDef_RawFastCallKeywords+0x285) [0x7fccbe0aa795]
# /usr/local/lib/libpython3.7m.so.1.0(_PyCFunction_FastCallKeywords+0x25) [0x7fccbe0aa8a5]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x8d00) [0x7fccbe088590]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDef_RawFastCallKeywords+0x2c0) [0x7fccbe0aa7d0]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDescr_FastCallKeywords+0x4a) [0x7fccbe0b2faa]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x8058) [0x7fccbe0878e8]
# /usr/local/lib/libpython3.7m.so.1.0(+0x676eb) [0x7fccbe07e6eb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x67e1) [0x7fccbe086071]
# /usr/local/lib/libpython3.7m.so.1.0(+0x676eb) [0x7fccbe07e6eb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x7f38) [0x7fccbe0877c8]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalCodeWithName+0x9a2) [0x7fccbe181d32]
# /usr/local/lib/libpython3.7m.so.1.0(_PyFunction_FastCallDict+0x1bb) [0x7fccbe0aa0eb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyObject_Call_Prepend+0xcd) [0x7fccbe0ab2bd]
# /usr/local/lib/libpython3.7m.so.1.0(PyObject_Call+0x75) [0x7fccbe0ac4c5]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x2da4) [0x7fccbe082634]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalCodeWithName+0x9a2) [0x7fccbe181d32]
# /usr/local/lib/libpython3.7m.so.1.0(_PyFunction_FastCallKeywords+0x93) [0x7fccbe0aa2a3]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x5eb6) [0x7fccbe085746]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/python3.7/lib-dynload/_asyncio.cpython-37m-x86_64-linux-gnu.so(+0x7d8f) [0x7fccbae5dd8f]
# /usr/local/lib/python3.7/lib-dynload/_asyncio.cpython-37m-x86_64-linux-gnu.so(+0x856e) [0x7fccbae5e56e]
# /usr/local/lib/libpython3.7m.so.1.0(_PyObject_FastCallKeywords+0xd3) [0x7fccbe0aa993]
# /usr/local/lib/libpython3.7m.so.1.0(+0x195719) [0x7fccbe1ac719]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDef_RawFastCallDict+0x24b) [0x7fccbe0aae6b]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_32354/1223850286.py in <module>
# ----> 1 fsa.to('cuda:0')
#
# /workspace/k2-fsa/k2/k2/python/k2/fsa.py in to(self, device)
#    1104             return self
#    1105
# -> 1106         ans = Fsa(self.arcs.to(device), properties=self.properties)
#    1107
#    1108         for name, value in self.named_tensor_attr(include_scores=False):
#
# RuntimeError:
#     Some bad things happened. Please read the above error messages and stack
#     trace. If you are using Python, the following command may be helpful:
#
#       gdb --args python /path/to/your/code.py
#
#     (You can use `gdb` to debug the code. Please consider compiling
#     a debug version of k2.).
#
#     If you are unable to fix it, please open an issue at:
#
#       https://github.com/k2-fsa/k2/issues/new

# %%
fsa.device
# Out:
# device(type='cpu')

# %%
fsa.is_cuda()
# Out:
# False

# %%
k2.ctc_loss
# Out:
# <function k2.ctc_loss.ctc_loss(decoding_graph: k2.fsa.Fsa, dense_fsa_vec: k2.dense_fsa_vec.DenseFsaVec, output_beam: float = 10, delay_penalty: float = 0.0, reduction: typing_extensions.Literal['none', 'mean', 'sum'] = 'sum', use_double_scores: bool = True, target_lengths: Union[torch.Tensor, NoneType] = None) -> torch.Tensor>

# %%
k2.with_cuda
# Out:
# False

# %%
s = '''
            0 1 1 0.1
            0 1 2 0.2
            1 2 -1 0.3
            2
'''

# %%
device=torch.device('cuda', 0)

# %%
fsa1 = k2.Fsa.from_str(s).to(device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_32354/3266709113.py in <module>
# ----> 1 fsa1 = k2.Fsa.from_str(s).to(device)
#
# /workspace/k2-fsa/k2/k2/python/k2/fsa.py in to(self, device)
#    1104             return self
#    1105
# -> 1106         ans = Fsa(self.arcs.to(device), properties=self.properties)
#    1107
#    1108         for name, value in self.named_tensor_attr(include_scores=False):
#
# RuntimeError:
#     Some bad things happened. Please read the above error messages and stack
#     trace. If you are using Python, the following command may be helpful:
#
#       gdb --args python /path/to/your/code.py
#
#     (You can use `gdb` to debug the code. Please consider compiling
#     a debug version of k2.).
#
#     If you are unable to fix it, please open an issue at:
#
#       https://github.com/k2-fsa/k2/issues/new
# [F] /workspace/k2-fsa/k2/k2/csrc/device_guard.h:66:static int32_t k2::DeviceGuard::GetDevice() k2 compiled without CUDA support
#
#
# [ Stack-Trace: ]
# /workspace/k2-fsa/k2/build_wo_cuda/lib/libk2_log.so(k2::internal::GetStackTrace()+0x34) [0x7fcb8c59aef4]
# /workspace/k2-fsa/k2/build_wo_cuda/lib/_k2.cpython-37m-x86_64-linux-gnu.so(+0x137e8a) [0x7fcb8d034e8a]
# /workspace/k2-fsa/k2/build_wo_cuda/lib/_k2.cpython-37m-x86_64-linux-gnu.so(+0xe1b37) [0x7fcb8cfdeb37]
# /workspace/k2-fsa/k2/build_wo_cuda/lib/_k2.cpython-37m-x86_64-linux-gnu.so(+0x166f5b) [0x7fcb8d063f5b]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDef_RawFastCallKeywords+0x2eb) [0x7fccbe0aa7fb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyCFunction_FastCallKeywords+0x25) [0x7fccbe0aa8a5]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x699e) [0x7fccbe08622e]
# /usr/local/lib/libpython3.7m.so.1.0(+0x676eb) [0x7fccbe07e6eb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x750d) [0x7fccbe086d9d]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalCodeWithName+0x9a2) [0x7fccbe181d32]
# /usr/local/lib/libpython3.7m.so.1.0(PyEval_EvalCodeEx+0x3e) [0x7fccbe181fae]
# /usr/local/lib/libpython3.7m.so.1.0(PyEval_EvalCode+0x1b) [0x7fccbe181fdb]
# /usr/local/lib/libpython3.7m.so.1.0(+0x16843d) [0x7fccbe17f43d]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDef_RawFastCallKeywords+0x285) [0x7fccbe0aa795]
# /usr/local/lib/libpython3.7m.so.1.0(_PyCFunction_FastCallKeywords+0x25) [0x7fccbe0aa8a5]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x8d00) [0x7fccbe088590]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDef_RawFastCallKeywords+0x2c0) [0x7fccbe0aa7d0]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDescr_FastCallKeywords+0x4a) [0x7fccbe0b2faa]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x8058) [0x7fccbe0878e8]
# /usr/local/lib/libpython3.7m.so.1.0(+0x676eb) [0x7fccbe07e6eb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x67e1) [0x7fccbe086071]
# /usr/local/lib/libpython3.7m.so.1.0(+0x676eb) [0x7fccbe07e6eb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x7f38) [0x7fccbe0877c8]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalCodeWithName+0x9a2) [0x7fccbe181d32]
# /usr/local/lib/libpython3.7m.so.1.0(_PyFunction_FastCallDict+0x1bb) [0x7fccbe0aa0eb]
# /usr/local/lib/libpython3.7m.so.1.0(_PyObject_Call_Prepend+0xcd) [0x7fccbe0ab2bd]
# /usr/local/lib/libpython3.7m.so.1.0(PyObject_Call+0x75) [0x7fccbe0ac4c5]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x2da4) [0x7fccbe082634]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalCodeWithName+0x9a2) [0x7fccbe181d32]
# /usr/local/lib/libpython3.7m.so.1.0(_PyFunction_FastCallKeywords+0x93) [0x7fccbe0aa2a3]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x5eb6) [0x7fccbe085746]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/libpython3.7m.so.1.0(_PyEval_EvalFrameDefault+0x6a84) [0x7fccbe086314]
# /usr/local/lib/libpython3.7m.so.1.0(+0xa4a56) [0x7fccbe0bba56]
# /usr/local/lib/python3.7/lib-dynload/_asyncio.cpython-37m-x86_64-linux-gnu.so(+0x7d8f) [0x7fccbae5dd8f]
# /usr/local/lib/python3.7/lib-dynload/_asyncio.cpython-37m-x86_64-linux-gnu.so(+0x856e) [0x7fccbae5e56e]
# /usr/local/lib/libpython3.7m.so.1.0(_PyObject_FastCallKeywords+0xd3) [0x7fccbe0aa993]
# /usr/local/lib/libpython3.7m.so.1.0(+0x195719) [0x7fccbe1ac719]
# /usr/local/lib/libpython3.7m.so.1.0(_PyMethodDef_RawFastCallDict+0x24b) [0x7fccbe0aae6b]

# %%
fsa1.device
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_32354/2068040482.py in <module>
# ----> 1 fsa1.device
#
# NameError: name 'fsa1' is not defined

# %%
fsa1.tensor_attr1 = torch.tensor([1, 2, 3]).to(device)
fsa1.tensor_attr2 = torch.tensor([4, 5, 6]).to(device)
fsa1.non_tensor_attr1 = 'fsa1'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_32354/1005787773.py in <module>
# ----> 1 fsa1.tensor_attr1 = torch.tensor([1, 2, 3]).to(device)
#       2 fsa1.tensor_attr2 = torch.tensor([4, 5, 6]).to(device)
#       3 fsa1.non_tensor_attr1 = 'fsa1'
#
# NameError: name 'fsa1' is not defined

# %%
fsa1.ragged_tensor_attr1 = \
        k2.RaggedTensor('[[1 2] [] [3 4 5]]').to(device)
fsa1.ragged_tensor_attr2 = \
        k2.RaggedTensor('[[1 20] [30] [5]]').to(device)

# %%
fsa2 = k2.Fsa.from_str(s).to(device)
fsa2.tensor_attr1 = torch.tensor([10, 20, 30]).to(device)
fsa2.tensor_attr3 = torch.tensor([40, 50, 60]).to(device)
fsa2.non_tensor_attr1 = 'fsa'
fsa2.non_tensor_attr2 = 'fsa2'

fsa2.ragged_tensor_attr1 = \
        k2.RaggedTensor('[[3] [4 5] [6 7]]').to(device)
fsa2.ragged_tensor_attr3 = \
        k2.RaggedTensor('[[1 0] [0] [-1]]').to(device)

# %%
fsa2.device

# %%
fsa_vec1 = k2.create_fsa_vec([fsa1])
fsa_vec2 = k2.create_fsa_vec([fsa2])
fsa_vec = k2.cat([fsa_vec1, fsa_vec2])

# %%
fsa_vec1.device

# %%
fsa_vec.device
# Out:
# device(type='cpu')

# %%
fsa.draw('test.svg')
